# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import cv2

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in d:\users\kwangho\anaconda3\envs\hexa_ai_1\lib\site-packages (4.5.1.48)
# Requirement already satisfied: numpy>=1.17.3 in d:\users\kwangho\anaconda3\envs\hexa_ai_1\lib\site-packages (from opencv-python) (1.20.2)

# %% [markdown]
# # image show

# %%
img = cv2.imread("Lenna.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print(img.shape)

plt.imshow(img)
plt.show()
# Out:
# (220, 220, 3)

# %% [markdown]
# # implement convolution
